# %%
# Set up the environment

import sys

# Add path for python to look into for modules installed using pip

# sys.path.append('/usr/local/lib/python3.7/site-packages/')

import os
import pandas as pd
from IPython.display import HTML

# Change into the correct directory

if os.getcwd() != os.path.expanduser('~') + '/fitpy/':
    os.chdir(os.path.expanduser('~') + '/fitpy/')
else:
    pass

# %%
data = pd.read_csv('/Users/maosa/fitr/data.csv', sep=',', )

# %%
data.head()
# Out:
#    No        Date Workout  Duration
# 0   1  2017-01-01    Rest         0
# 1   2  2017-01-02    Rest         0
# 2   3  2017-01-03    Rest         0
# 3   4  2017-01-04    Rest         0
# 4   5  2017-01-05   Chest        68

# %%
workouts = data['Workout'].unique()

workouts
# Out:
# array(['Rest', 'Chest', 'Pull 1', 'Running', 'Shoulders and Arms',
#        'Pull 2', 'Insane Chest and Dips', 'Cardio',
#        'Insane Chest and Biceps', 'Pull 2 + Cardio', 'Texas + Cardio',
#        'Insane Chest', 'Cobra Back', 'Dorians Challenge',
#        'Insane Chest + Cardio', 'Back + Cardio', 'Texas',
#        'Pull 1 + Cardio', 'Cobra Back + Abs', 'Legs', 'Back',
#        'Chest + Cardio', 'Chest + Back', 'Chest and Biceps',
#        'Chest and Biceps + Back', 'Upper Body',
#        'Chest and Triceps and Core', 'Back and Biceps and Core',
#        'Back and Biceps', 'Chest and Core', 'Legs and Core',
#        'Chest and Core and Rotator Cuffs', 'Back and Knee Conditioning',
#        'Chest and Back and Knee Conditioning',
#        'Half Squats and Chest and Core', 'Insane Chest and Push and Core',
#        'Cycling + Cobra Back', 'Compound and Core',
#        'Insane Chest and Push', 'Cobra Back and Core', 'Compound',
#        "Can't Walk and Core", 'Cobra Back and Pull', "Can't Walk",
#        'Texas and Dips and Core', 'Compound + Chest', 'Back and Core',
#        'Chest and Back', 'Compound 1', 'Compound 2', 'Compound 3',
#        'Cross training', 'Multisport', 'Multisport (Back)',
#        'Multisport (Chest)', 'Multisport (Legs)', 'Bouldering',
#        'Basketball', 'Surfing'], dtype=object)

# %%
chest = [
    'Chest', 'Insane Chest and Dips', 'Insane Chest and Biceps', 'Insane Chest',
    'Chest and Biceps', 'Chest and Triceps and Core', 'Chest and Core', 'Chest and Core and Rotator Cuffs',
    'Half Squats and Chest and Core', 'Insane Chest and Push and Core', 'Insane Chest and Push',
    'Multisport (Chest)'
]

back = [
    'Back', 'Pull 1', 'Pull 2', 'Cobra Back', 'Back and Biceps and Core', 'Back and Biceps',
    'Back and Knee Conditioning', 'Cobra Back and Core', 'Cobra Back and Pull', 'Back and Core',
    'Multisport (Back)'
]

legs = ['Legs', 'Legs and Core', "Can't Walk and Core", "Can't Walk", 'Multisport (Legs)']

compound = [
    'Compound', 'Texas', 'Chest and Back and Knee Conditioning',
    'Compound and Core', 'Texas and Dips and Core',
    'Chest and Back', 'Compound 1', 'Compound 2', 'Compound 3', 'Cross training', 'Multisport', 'Bouldering'
]

cardio = ['Running', 'Cardio', 'Basketball', 'Surfing']

other = [
    'Shoulders and Arms', 'Dorians Challenge', 'Upper Body'
]

rest = 'Rest'

double = [s for s in workouts if '+' in s]

if (len(workouts) != len(chest) + len(back) + len(legs) +
    len(compound) + len(cardio) + len(rest) + len(double)):
    
    miss = len(workouts) - (len(chest) + len(back) + len(legs) +
    len(compound) + len(cardio) + len(rest) + len(double))
    
    print('Mismatch of', miss)

# %%
# Simplify workout names

simple = []

for w in range(len(data['Workout'])):
    
    workout = data['Workout'][w]
    
    if workout in chest:
        simple.append('Chest')
    elif workout in back:
        simple.append('Back')
    elif workout in legs:
        simple.append('Legs')
    elif workout in compound:
        simple.append('Compound')
    elif workout in cardio:
        simple.append('Cardio')
    elif workout in rest:
        simple.append('Rest')
    elif '+' in workout:
        simple.append(workout)
    else:
        simple.append('Other')
        
if len(simple) == len(data):
    data['simple'] = simple

# Categorise workoute

category = []

for w in range(len(data['Workout'])):
    
    workout = data['Workout'][w]
    
    if workout in chest:
        category.append('chest')
    elif workout in back:
        category.append('back')
    elif workout in legs:
        category.append('legs')
    elif workout in compound:
        category.append('compound')
    elif workout in cardio:
        category.append('cardio')
    elif workout in rest:
        category.append('rest')
    elif '+' in workout:
        category.append('double_workout')
    else:
        category.append('other')
        
if len(category) == len(data):
    data['Category'] = category
    
# Convert dates to datetime
    
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# Simplify workout names

data['Workout'] = data['simple']

data.drop(labels='simple', axis=1, inplace=True)

# Check dates and reverse if necessary
first = data['Date'][0]
last = data['Date'][data.shape[0] - 1]

if first < last:
    data.sort_index(ascending=False, inplace=True)
else:
    pass

# %%
data
# Out:
#         No       Date   Workout  Duration  Category
# 1176  1177 2020-03-22  Compound        39  compound
# 1175  1176 2020-03-21    Cardio        42    cardio
# 1174  1175 2020-03-20      Rest         0      rest
# 1173  1174 2020-03-19      Rest         0      rest
# 1172  1173 2020-03-18  Compound        45  compound
# ...    ...        ...       ...       ...       ...
# 4        5 2017-01-05     Chest        68     chest
# 3        4 2017-01-04      Rest         0      rest
# 2        3 2017-01-03      Rest         0      rest
# 1        2 2017-01-02      Rest         0      rest
# 0        1 2017-01-01      Rest         0      rest
#
# [1177 rows x 5 columns]

# %%
data.to_csv(os.getcwd() + '/data.csv', sep=',', index=False, header=True)

# %%
test = pd.read_csv('data.csv', sep=',')

# %%
test
# Out:
#         No        Date   Workout  Duration  Category
# 0     1177  2020-03-22  Compound        39  compound
# 1     1176  2020-03-21    Cardio        42    cardio
# 2     1175  2020-03-20      Rest         0      rest
# 3     1174  2020-03-19      Rest         0      rest
# 4     1173  2020-03-18  Compound        45  compound
# ...    ...         ...       ...       ...       ...
# 1172     5  2017-01-05     Chest        68     chest
# 1173     4  2017-01-04      Rest         0      rest
# 1174     3  2017-01-03      Rest         0      rest
# 1175     2  2017-01-02      Rest         0      rest
# 1176     1  2017-01-01      Rest         0      rest
#
# [1177 rows x 5 columns]

# %%
test.to_dict(orient='records')
# Out:
# [{'No': 1177,
#   'Date': '2020-03-22',
#   'Workout': 'Compound',
#   'Duration': 39,
#   'Category': 'compound'},
#  {'No': 1176,
#   'Date': '2020-03-21',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 1175,
#   'Date': '2020-03-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1174,
#   'Date': '2020-03-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1173,
#   'Date': '2020-03-18',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 1172,
#   'Date': '2020-03-17',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1171,
#   'Date': '2020-03-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1170,
#   'Date': '2020-03-15',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1169,
#   'Date': '2020-03-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1168,
#   'Date': '2020-03-13',
#   'Workout': 'Cardio',
#   'Duration': 36,
#   'Category': 'cardio'},
#  {'No': 1167,
#   'Date': '2020-03-12',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1166,
#   'Date': '2020-03-11',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1165,
#   'Date': '2020-03-10',
#   'Workout': 'Back',
#   'Duration': 33,
#   'Category': 'back'},
#  {'No': 1164,
#   'Date': '2020-03-09',
#   'Workout': 'Chest',
#   'Duration': 35,
#   'Category': 'chest'},
#  {'No': 1163,
#   'Date': '2020-03-08',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1162,
#   'Date': '2020-03-07',
#   'Workout': 'Cardio',
#   'Duration': 40,
#   'Category': 'cardio'},
#  {'No': 1161,
#   'Date': '2020-03-06',
#   'Workout': 'Back',
#   'Duration': 38,
#   'Category': 'back'},
#  {'No': 1160,
#   'Date': '2020-03-05',
#   'Workout': 'Chest',
#   'Duration': 32,
#   'Category': 'chest'},
#  {'No': 1159,
#   'Date': '2020-03-04',
#   'Workout': 'Legs',
#   'Duration': 29,
#   'Category': 'legs'},
#  {'No': 1158,
#   'Date': '2020-03-03',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 1157,
#   'Date': '2020-03-02',
#   'Workout': 'Chest',
#   'Duration': 28,
#   'Category': 'chest'},
#  {'No': 1156,
#   'Date': '2020-03-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1155,
#   'Date': '2020-02-29',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1154,
#   'Date': '2020-02-28',
#   'Workout': 'Back',
#   'Duration': 35,
#   'Category': 'back'},
#  {'No': 1153,
#   'Date': '2020-02-27',
#   'Workout': 'Chest',
#   'Duration': 36,
#   'Category': 'chest'},
#  {'No': 1152,
#   'Date': '2020-02-26',
#   'Workout': 'Legs',
#   'Duration': 24,
#   'Category': 'legs'},
#  {'No': 1151,
#   'Date': '2020-02-25',
#   'Workout': 'Back',
#   'Duration': 35,
#   'Category': 'back'},
#  {'No': 1150,
#   'Date': '2020-02-24',
#   'Workout': 'Chest',
#   'Duration': 35,
#   'Category': 'chest'},
#  {'No': 1149,
#   'Date': '2020-02-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1148,
#   'Date': '2020-02-22',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 1147,
#   'Date': '2020-02-21',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 1146,
#   'Date': '2020-02-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1145,
#   'Date': '2020-02-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1144,
#   'Date': '2020-02-18',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1143,
#   'Date': '2020-02-17',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1142,
#   'Date': '2020-02-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1141,
#   'Date': '2020-02-15',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1140,
#   'Date': '2020-02-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1139,
#   'Date': '2020-02-13',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1138,
#   'Date': '2020-02-12',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1137,
#   'Date': '2020-02-11',
#   'Workout': 'Back',
#   'Duration': 31,
#   'Category': 'back'},
#  {'No': 1136,
#   'Date': '2020-02-10',
#   'Workout': 'Chest',
#   'Duration': 34,
#   'Category': 'chest'},
#  {'No': 1135,
#   'Date': '2020-02-09',
#   'Workout': 'Cardio',
#   'Duration': 40,
#   'Category': 'cardio'},
#  {'No': 1134,
#   'Date': '2020-02-08',
#   'Workout': 'Cardio',
#   'Duration': 41,
#   'Category': 'cardio'},
#  {'No': 1133,
#   'Date': '2020-02-07',
#   'Workout': 'Back',
#   'Duration': 33,
#   'Category': 'back'},
#  {'No': 1132,
#   'Date': '2020-02-06',
#   'Workout': 'Chest',
#   'Duration': 35,
#   'Category': 'chest'},
#  {'No': 1131,
#   'Date': '2020-02-05',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 1130,
#   'Date': '2020-02-04',
#   'Workout': 'Back',
#   'Duration': 33,
#   'Category': 'back'},
#  {'No': 1129,
#   'Date': '2020-02-03',
#   'Workout': 'Chest',
#   'Duration': 36,
#   'Category': 'chest'},
#  {'No': 1128,
#   'Date': '2020-02-02',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1127,
#   'Date': '2020-02-01',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 1126,
#   'Date': '2020-01-31',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 1125,
#   'Date': '2020-01-30',
#   'Workout': 'Chest',
#   'Duration': 33,
#   'Category': 'chest'},
#  {'No': 1124,
#   'Date': '2020-01-29',
#   'Workout': 'Legs',
#   'Duration': 29,
#   'Category': 'legs'},
#  {'No': 1123,
#   'Date': '2020-01-28',
#   'Workout': 'Back',
#   'Duration': 34,
#   'Category': 'back'},
#  {'No': 1122,
#   'Date': '2020-01-27',
#   'Workout': 'Chest',
#   'Duration': 37,
#   'Category': 'chest'},
#  {'No': 1121,
#   'Date': '2020-01-26',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1120,
#   'Date': '2020-01-25',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1119,
#   'Date': '2020-01-24',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 1118,
#   'Date': '2020-01-23',
#   'Workout': 'Chest',
#   'Duration': 36,
#   'Category': 'chest'},
#  {'No': 1117,
#   'Date': '2020-01-22',
#   'Workout': 'Legs',
#   'Duration': 27,
#   'Category': 'legs'},
#  {'No': 1116,
#   'Date': '2020-01-21',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 1115,
#   'Date': '2020-01-20',
#   'Workout': 'Chest',
#   'Duration': 35,
#   'Category': 'chest'},
#  {'No': 1114,
#   'Date': '2020-01-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1113,
#   'Date': '2020-01-18',
#   'Workout': 'Legs',
#   'Duration': 27,
#   'Category': 'legs'},
#  {'No': 1112,
#   'Date': '2020-01-17',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 1111,
#   'Date': '2020-01-16',
#   'Workout': 'Chest',
#   'Duration': 38,
#   'Category': 'chest'},
#  {'No': 1110,
#   'Date': '2020-01-15',
#   'Workout': 'Legs',
#   'Duration': 29,
#   'Category': 'legs'},
#  {'No': 1109,
#   'Date': '2020-01-14',
#   'Workout': 'Back',
#   'Duration': 34,
#   'Category': 'back'},
#  {'No': 1108,
#   'Date': '2020-01-13',
#   'Workout': 'Chest',
#   'Duration': 37,
#   'Category': 'chest'},
#  {'No': 1107,
#   'Date': '2020-01-12',
#   'Workout': 'Legs',
#   'Duration': 26,
#   'Category': 'legs'},
#  {'No': 1106,
#   'Date': '2020-01-11',
#   'Workout': 'Back',
#   'Duration': 36,
#   'Category': 'back'},
#  {'No': 1105,
#   'Date': '2020-01-10',
#   'Workout': 'Chest',
#   'Duration': 35,
#   'Category': 'chest'},
#  {'No': 1104,
#   'Date': '2020-01-09',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1103,
#   'Date': '2020-01-08',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1102,
#   'Date': '2020-01-07',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1101,
#   'Date': '2020-01-06',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1100,
#   'Date': '2020-01-05',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1099,
#   'Date': '2020-01-04',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1098,
#   'Date': '2020-01-03',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1097,
#   'Date': '2020-01-02',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1096,
#   'Date': '2020-01-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1095,
#   'Date': '2019-12-31',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1094,
#   'Date': '2019-12-30',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1093,
#   'Date': '2019-12-29',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1092,
#   'Date': '2019-12-28',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1091,
#   'Date': '2019-12-27',
#   'Workout': 'Compound',
#   'Duration': 40,
#   'Category': 'compound'},
#  {'No': 1090,
#   'Date': '2019-12-26',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1089,
#   'Date': '2019-12-25',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1088,
#   'Date': '2019-12-24',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 1087,
#   'Date': '2019-12-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1086,
#   'Date': '2019-12-22',
#   'Workout': 'Compound',
#   'Duration': 40,
#   'Category': 'compound'},
#  {'No': 1085,
#   'Date': '2019-12-21',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1084,
#   'Date': '2019-12-20',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 1083,
#   'Date': '2019-12-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1082,
#   'Date': '2019-12-18',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1081,
#   'Date': '2019-12-17',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 1080,
#   'Date': '2019-12-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1079,
#   'Date': '2019-12-15',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 1078,
#   'Date': '2019-12-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1077,
#   'Date': '2019-12-13',
#   'Workout': 'Compound',
#   'Duration': 48,
#   'Category': 'compound'},
#  {'No': 1076,
#   'Date': '2019-12-12',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1075,
#   'Date': '2019-12-11',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 1074,
#   'Date': '2019-12-10',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1073,
#   'Date': '2019-12-09',
#   'Workout': 'Compound',
#   'Duration': 46,
#   'Category': 'compound'},
#  {'No': 1072,
#   'Date': '2019-12-08',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1071,
#   'Date': '2019-12-07',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1070,
#   'Date': '2019-12-06',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 1069,
#   'Date': '2019-12-05',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 1068,
#   'Date': '2019-12-04',
#   'Workout': 'Chest',
#   'Duration': 46,
#   'Category': 'chest'},
#  {'No': 1067,
#   'Date': '2019-12-03',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 1066,
#   'Date': '2019-12-02',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 1065,
#   'Date': '2019-12-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1064,
#   'Date': '2019-11-30',
#   'Workout': 'Compound',
#   'Duration': 46,
#   'Category': 'compound'},
#  {'No': 1063,
#   'Date': '2019-11-29',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 1062,
#   'Date': '2019-11-28',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 1061,
#   'Date': '2019-11-27',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 1060,
#   'Date': '2019-11-26',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 1059,
#   'Date': '2019-11-25',
#   'Workout': 'Chest',
#   'Duration': 45,
#   'Category': 'chest'},
#  {'No': 1058,
#   'Date': '2019-11-24',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1057,
#   'Date': '2019-11-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1056,
#   'Date': '2019-11-22',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 1055,
#   'Date': '2019-11-21',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 1054,
#   'Date': '2019-11-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1053,
#   'Date': '2019-11-19',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 1052,
#   'Date': '2019-11-18',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 1051,
#   'Date': '2019-11-17',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1050,
#   'Date': '2019-11-16',
#   'Workout': 'Compound',
#   'Duration': 49,
#   'Category': 'compound'},
#  {'No': 1049,
#   'Date': '2019-11-15',
#   'Workout': 'Back',
#   'Duration': 48,
#   'Category': 'back'},
#  {'No': 1048,
#   'Date': '2019-11-14',
#   'Workout': 'Chest',
#   'Duration': 47,
#   'Category': 'chest'},
#  {'No': 1047,
#   'Date': '2019-11-13',
#   'Workout': 'Cardio',
#   'Duration': 41,
#   'Category': 'cardio'},
#  {'No': 1046,
#   'Date': '2019-11-12',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 1045,
#   'Date': '2019-11-11',
#   'Workout': 'Chest',
#   'Duration': 46,
#   'Category': 'chest'},
#  {'No': 1044,
#   'Date': '2019-11-10',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1043,
#   'Date': '2019-11-09',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1042,
#   'Date': '2019-11-08',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 1041,
#   'Date': '2019-11-07',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 1040,
#   'Date': '2019-11-06',
#   'Workout': 'Cardio',
#   'Duration': 43,
#   'Category': 'cardio'},
#  {'No': 1039,
#   'Date': '2019-11-05',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 1038,
#   'Date': '2019-11-04',
#   'Workout': 'Chest',
#   'Duration': 45,
#   'Category': 'chest'},
#  {'No': 1037,
#   'Date': '2019-11-03',
#   'Workout': 'Cardio',
#   'Duration': 37,
#   'Category': 'cardio'},
#  {'No': 1036,
#   'Date': '2019-11-02',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 1035,
#   'Date': '2019-11-01',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 1034,
#   'Date': '2019-10-31',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 1033,
#   'Date': '2019-10-30',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 1032,
#   'Date': '2019-10-29',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 1031,
#   'Date': '2019-10-28',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 1030,
#   'Date': '2019-10-27',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1029,
#   'Date': '2019-10-26',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1028,
#   'Date': '2019-10-25',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 1027,
#   'Date': '2019-10-24',
#   'Workout': 'Legs',
#   'Duration': 27,
#   'Category': 'legs'},
#  {'No': 1026,
#   'Date': '2019-10-23',
#   'Workout': 'Back',
#   'Duration': 35,
#   'Category': 'back'},
#  {'No': 1025,
#   'Date': '2019-10-22',
#   'Workout': 'Chest',
#   'Duration': 37,
#   'Category': 'chest'},
#  {'No': 1024,
#   'Date': '2019-10-21',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 1023,
#   'Date': '2019-10-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1022,
#   'Date': '2019-10-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1021,
#   'Date': '2019-10-18',
#   'Workout': 'Legs',
#   'Duration': 29,
#   'Category': 'legs'},
#  {'No': 1020,
#   'Date': '2019-10-17',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 1019,
#   'Date': '2019-10-16',
#   'Workout': 'Chest',
#   'Duration': 38,
#   'Category': 'chest'},
#  {'No': 1018,
#   'Date': '2019-10-15',
#   'Workout': 'Legs',
#   'Duration': 32,
#   'Category': 'legs'},
#  {'No': 1017,
#   'Date': '2019-10-14',
#   'Workout': 'Back',
#   'Duration': 35,
#   'Category': 'back'},
#  {'No': 1016,
#   'Date': '2019-10-13',
#   'Workout': 'Chest',
#   'Duration': 37,
#   'Category': 'chest'},
#  {'No': 1015,
#   'Date': '2019-10-12',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1014,
#   'Date': '2019-10-11',
#   'Workout': 'Compound',
#   'Duration': 44,
#   'Category': 'compound'},
#  {'No': 1013,
#   'Date': '2019-10-10',
#   'Workout': 'Legs',
#   'Duration': 26,
#   'Category': 'legs'},
#  {'No': 1012,
#   'Date': '2019-10-09',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 1011,
#   'Date': '2019-10-08',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 1010,
#   'Date': '2019-10-07',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 1009,
#   'Date': '2019-10-06',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1008,
#   'Date': '2019-10-05',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1007,
#   'Date': '2019-10-04',
#   'Workout': 'Compound',
#   'Duration': 44,
#   'Category': 'compound'},
#  {'No': 1006,
#   'Date': '2019-10-03',
#   'Workout': 'Legs',
#   'Duration': 30,
#   'Category': 'legs'},
#  {'No': 1005,
#   'Date': '2019-10-02',
#   'Workout': 'Back',
#   'Duration': 35,
#   'Category': 'back'},
#  {'No': 1004,
#   'Date': '2019-10-01',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 1003,
#   'Date': '2019-09-30',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1002,
#   'Date': '2019-09-29',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1001,
#   'Date': '2019-09-28',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 1000,
#   'Date': '2019-09-27',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 999,
#   'Date': '2019-09-26',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 998,
#   'Date': '2019-09-25',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 997,
#   'Date': '2019-09-24',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 996,
#   'Date': '2019-09-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 995,
#   'Date': '2019-09-22',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 994,
#   'Date': '2019-09-21',
#   'Workout': 'Compound',
#   'Duration': 37,
#   'Category': 'compound'},
#  {'No': 993,
#   'Date': '2019-09-20',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 992,
#   'Date': '2019-09-19',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 991,
#   'Date': '2019-09-18',
#   'Workout': 'Legs',
#   'Duration': 31,
#   'Category': 'legs'},
#  {'No': 990,
#   'Date': '2019-09-17',
#   'Workout': 'Back',
#   'Duration': 34,
#   'Category': 'back'},
#  {'No': 989,
#   'Date': '2019-09-16',
#   'Workout': 'Chest',
#   'Duration': 38,
#   'Category': 'chest'},
#  {'No': 988,
#   'Date': '2019-09-15',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 987,
#   'Date': '2019-09-14',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 986,
#   'Date': '2019-09-13',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 985,
#   'Date': '2019-09-12',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 984,
#   'Date': '2019-09-11',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 983,
#   'Date': '2019-09-10',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 982,
#   'Date': '2019-09-09',
#   'Workout': 'Compound',
#   'Duration': 50,
#   'Category': 'compound'},
#  {'No': 981,
#   'Date': '2019-09-08',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 980,
#   'Date': '2019-09-07',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 979,
#   'Date': '2019-09-06',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 978,
#   'Date': '2019-09-05',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 977,
#   'Date': '2019-09-04',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 976,
#   'Date': '2019-09-03',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 975,
#   'Date': '2019-09-02',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 974,
#   'Date': '2019-09-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 973,
#   'Date': '2019-08-31',
#   'Workout': 'Compound',
#   'Duration': 46,
#   'Category': 'compound'},
#  {'No': 972,
#   'Date': '2019-08-30',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 971,
#   'Date': '2019-08-29',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 970,
#   'Date': '2019-08-28',
#   'Workout': 'Legs',
#   'Duration': 22,
#   'Category': 'legs'},
#  {'No': 969,
#   'Date': '2019-08-27',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 968,
#   'Date': '2019-08-26',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 967,
#   'Date': '2019-08-25',
#   'Workout': 'Cardio',
#   'Duration': 57,
#   'Category': 'cardio'},
#  {'No': 966,
#   'Date': '2019-08-24',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 965,
#   'Date': '2019-08-23',
#   'Workout': 'Back',
#   'Duration': 38,
#   'Category': 'back'},
#  {'No': 964,
#   'Date': '2019-08-22',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 963,
#   'Date': '2019-08-21',
#   'Workout': 'Legs',
#   'Duration': 35,
#   'Category': 'legs'},
#  {'No': 962,
#   'Date': '2019-08-20',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 961,
#   'Date': '2019-08-19',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 960,
#   'Date': '2019-08-18',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 959,
#   'Date': '2019-08-17',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 958,
#   'Date': '2019-08-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 957,
#   'Date': '2019-08-15',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 956,
#   'Date': '2019-08-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 955,
#   'Date': '2019-08-13',
#   'Workout': 'Compound',
#   'Duration': 46,
#   'Category': 'compound'},
#  {'No': 954,
#   'Date': '2019-08-12',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 953,
#   'Date': '2019-08-11',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 952,
#   'Date': '2019-08-10',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 951,
#   'Date': '2019-08-09',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 950,
#   'Date': '2019-08-08',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 949,
#   'Date': '2019-08-07',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 948,
#   'Date': '2019-08-06',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 947,
#   'Date': '2019-08-05',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 946,
#   'Date': '2019-08-04',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 945,
#   'Date': '2019-08-03',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 944,
#   'Date': '2019-08-02',
#   'Workout': 'Compound',
#   'Duration': 39,
#   'Category': 'compound'},
#  {'No': 943,
#   'Date': '2019-08-01',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 942,
#   'Date': '2019-07-31',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 941,
#   'Date': '2019-07-30',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 940,
#   'Date': '2019-07-29',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 939,
#   'Date': '2019-07-28',
#   'Workout': 'Cardio',
#   'Duration': 54,
#   'Category': 'cardio'},
#  {'No': 938,
#   'Date': '2019-07-27',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 937,
#   'Date': '2019-07-26',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 936,
#   'Date': '2019-07-25',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 935,
#   'Date': '2019-07-24',
#   'Workout': 'Compound',
#   'Duration': 60,
#   'Category': 'compound'},
#  {'No': 934,
#   'Date': '2019-07-23',
#   'Workout': 'Chest',
#   'Duration': 36,
#   'Category': 'chest'},
#  {'No': 933,
#   'Date': '2019-07-22',
#   'Workout': 'Compound',
#   'Duration': 90,
#   'Category': 'compound'},
#  {'No': 932,
#   'Date': '2019-07-21',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 931,
#   'Date': '2019-07-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 930,
#   'Date': '2019-07-19',
#   'Workout': 'Compound',
#   'Duration': 56,
#   'Category': 'compound'},
#  {'No': 929,
#   'Date': '2019-07-18',
#   'Workout': 'Back',
#   'Duration': 51,
#   'Category': 'back'},
#  {'No': 928,
#   'Date': '2019-07-17',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 927,
#   'Date': '2019-07-16',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 926,
#   'Date': '2019-07-15',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 925,
#   'Date': '2019-07-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 924,
#   'Date': '2019-07-13',
#   'Workout': 'Compound',
#   'Duration': 44,
#   'Category': 'compound'},
#  {'No': 923,
#   'Date': '2019-07-12',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 922,
#   'Date': '2019-07-11',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 921,
#   'Date': '2019-07-10',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 920,
#   'Date': '2019-07-09',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 919,
#   'Date': '2019-07-08',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 918,
#   'Date': '2019-07-07',
#   'Workout': 'Cardio',
#   'Duration': 55,
#   'Category': 'cardio'},
#  {'No': 917,
#   'Date': '2019-07-06',
#   'Workout': 'Cardio',
#   'Duration': 52,
#   'Category': 'cardio'},
#  {'No': 916,
#   'Date': '2019-07-05',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 915,
#   'Date': '2019-07-04',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 914,
#   'Date': '2019-07-03',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 913,
#   'Date': '2019-07-02',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 912,
#   'Date': '2019-07-01',
#   'Workout': 'Compound',
#   'Duration': 120,
#   'Category': 'compound'},
#  {'No': 911,
#   'Date': '2019-06-30',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 910,
#   'Date': '2019-06-29',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 909,
#   'Date': '2019-06-28',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 908,
#   'Date': '2019-06-27',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 907,
#   'Date': '2019-06-26',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 906,
#   'Date': '2019-06-25',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 905,
#   'Date': '2019-06-24',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 904,
#   'Date': '2019-06-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 903,
#   'Date': '2019-06-22',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 902,
#   'Date': '2019-06-21',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 901,
#   'Date': '2019-06-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 900,
#   'Date': '2019-06-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 899,
#   'Date': '2019-06-18',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 898,
#   'Date': '2019-06-17',
#   'Workout': 'Cardio',
#   'Duration': 180,
#   'Category': 'cardio'},
#  {'No': 897,
#   'Date': '2019-06-16',
#   'Workout': 'Cardio',
#   'Duration': 120,
#   'Category': 'cardio'},
#  {'No': 896,
#   'Date': '2019-06-15',
#   'Workout': 'Cardio',
#   'Duration': 120,
#   'Category': 'cardio'},
#  {'No': 895,
#   'Date': '2019-06-14',
#   'Workout': 'Cardio',
#   'Duration': 120,
#   'Category': 'cardio'},
#  {'No': 894,
#   'Date': '2019-06-13',
#   'Workout': 'Cardio',
#   'Duration': 120,
#   'Category': 'cardio'},
#  {'No': 893,
#   'Date': '2019-06-12',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 892,
#   'Date': '2019-06-11',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 891,
#   'Date': '2019-06-10',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 890,
#   'Date': '2019-06-09',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 889,
#   'Date': '2019-06-08',
#   'Workout': 'Legs',
#   'Duration': 29,
#   'Category': 'legs'},
#  {'No': 888,
#   'Date': '2019-06-07',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 887,
#   'Date': '2019-06-06',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 886,
#   'Date': '2019-06-05',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 885,
#   'Date': '2019-06-04',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 884,
#   'Date': '2019-06-03',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 883,
#   'Date': '2019-06-02',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 882,
#   'Date': '2019-06-01',
#   'Workout': 'Back',
#   'Duration': 36,
#   'Category': 'back'},
#  {'No': 881,
#   'Date': '2019-05-31',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 880,
#   'Date': '2019-05-30',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 879,
#   'Date': '2019-05-29',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 878,
#   'Date': '2019-05-28',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 877,
#   'Date': '2019-05-27',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 876,
#   'Date': '2019-05-26',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 875,
#   'Date': '2019-05-25',
#   'Workout': 'Legs',
#   'Duration': 33,
#   'Category': 'legs'},
#  {'No': 874,
#   'Date': '2019-05-24',
#   'Workout': 'Back',
#   'Duration': 40,
#   'Category': 'back'},
#  {'No': 873,
#   'Date': '2019-05-23',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 872,
#   'Date': '2019-05-22',
#   'Workout': 'Cardio',
#   'Duration': 41,
#   'Category': 'cardio'},
#  {'No': 871,
#   'Date': '2019-05-21',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 870,
#   'Date': '2019-05-20',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 869,
#   'Date': '2019-05-19',
#   'Workout': 'Cardio',
#   'Duration': 41,
#   'Category': 'cardio'},
#  {'No': 868,
#   'Date': '2019-05-18',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 867,
#   'Date': '2019-05-17',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 866,
#   'Date': '2019-05-16',
#   'Workout': 'Cardio',
#   'Duration': 38,
#   'Category': 'cardio'},
#  {'No': 865,
#   'Date': '2019-05-15',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 864,
#   'Date': '2019-05-14',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 863,
#   'Date': '2019-05-13',
#   'Workout': 'Cardio',
#   'Duration': 40,
#   'Category': 'cardio'},
#  {'No': 862,
#   'Date': '2019-05-12',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 861,
#   'Date': '2019-05-11',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 860,
#   'Date': '2019-05-10',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 859,
#   'Date': '2019-05-09',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 858,
#   'Date': '2019-05-08',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 857,
#   'Date': '2019-05-07',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 856,
#   'Date': '2019-05-06',
#   'Workout': 'Cardio',
#   'Duration': 32,
#   'Category': 'cardio'},
#  {'No': 855,
#   'Date': '2019-05-05',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 854,
#   'Date': '2019-05-04',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 853,
#   'Date': '2019-05-03',
#   'Workout': 'Back',
#   'Duration': 37,
#   'Category': 'back'},
#  {'No': 852,
#   'Date': '2019-05-02',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 851,
#   'Date': '2019-05-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 850,
#   'Date': '2019-04-30',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 849,
#   'Date': '2019-04-29',
#   'Workout': 'Chest',
#   'Duration': 46,
#   'Category': 'chest'},
#  {'No': 848,
#   'Date': '2019-04-28',
#   'Workout': 'Back',
#   'Duration': 38,
#   'Category': 'back'},
#  {'No': 847,
#   'Date': '2019-04-27',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 846,
#   'Date': '2019-04-26',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 845,
#   'Date': '2019-04-25',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 844,
#   'Date': '2019-04-24',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 843,
#   'Date': '2019-04-23',
#   'Workout': 'Back',
#   'Duration': 49,
#   'Category': 'back'},
#  {'No': 842,
#   'Date': '2019-04-22',
#   'Workout': 'Chest',
#   'Duration': 54,
#   'Category': 'chest'},
#  {'No': 841,
#   'Date': '2019-04-21',
#   'Workout': 'Back',
#   'Duration': 51,
#   'Category': 'back'},
#  {'No': 840,
#   'Date': '2019-04-20',
#   'Workout': 'Chest',
#   'Duration': 51,
#   'Category': 'chest'},
#  {'No': 839,
#   'Date': '2019-04-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 838,
#   'Date': '2019-04-18',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  {'No': 837,
#   'Date': '2019-04-17',
#   'Workout': 'Chest',
#   'Duration': 53,
#   'Category': 'chest'},
#  {'No': 836,
#   'Date': '2019-04-16',
#   'Workout': 'Back',
#   'Duration': 48,
#   'Category': 'back'},
#  {'No': 835,
#   'Date': '2019-04-15',
#   'Workout': 'Chest',
#   'Duration': 49,
#   'Category': 'chest'},
#  {'No': 834,
#   'Date': '2019-04-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 833,
#   'Date': '2019-04-13',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 832,
#   'Date': '2019-04-12',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 831,
#   'Date': '2019-04-11',
#   'Workout': 'Chest',
#   'Duration': 37,
#   'Category': 'chest'},
#  {'No': 830,
#   'Date': '2019-04-10',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 829,
#   'Date': '2019-04-09',
#   'Workout': 'Chest',
#   'Duration': 46,
#   'Category': 'chest'},
#  {'No': 828,
#   'Date': '2019-04-08',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 827,
#   'Date': '2019-04-07',
#   'Workout': 'Chest',
#   'Duration': 35,
#   'Category': 'chest'},
#  {'No': 826,
#   'Date': '2019-04-06',
#   'Workout': 'Cardio',
#   'Duration': 120,
#   'Category': 'cardio'},
#  {'No': 825,
#   'Date': '2019-04-05',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 824,
#   'Date': '2019-04-04',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 823,
#   'Date': '2019-04-03',
#   'Workout': 'Back',
#   'Duration': 48,
#   'Category': 'back'},
#  {'No': 822,
#   'Date': '2019-04-02',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 821,
#   'Date': '2019-04-01',
#   'Workout': 'Back',
#   'Duration': 48,
#   'Category': 'back'},
#  {'No': 820,
#   'Date': '2019-03-31',
#   'Workout': 'Cardio',
#   'Duration': 60,
#   'Category': 'cardio'},
#  {'No': 819,
#   'Date': '2019-03-30',
#   'Workout': 'Chest',
#   'Duration': 48,
#   'Category': 'chest'},
#  {'No': 818,
#   'Date': '2019-03-29',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  {'No': 817,
#   'Date': '2019-03-28',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 816,
#   'Date': '2019-03-27',
#   'Workout': 'Back',
#   'Duration': 49,
#   'Category': 'back'},
#  {'No': 815,
#   'Date': '2019-03-26',
#   'Workout': 'Chest',
#   'Duration': 50,
#   'Category': 'chest'},
#  {'No': 814,
#   'Date': '2019-03-25',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  {'No': 813,
#   'Date': '2019-03-24',
#   'Workout': 'Chest',
#   'Duration': 50,
#   'Category': 'chest'},
#  {'No': 812,
#   'Date': '2019-03-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 811,
#   'Date': '2019-03-22',
#   'Workout': 'Compound',
#   'Duration': 39,
#   'Category': 'compound'},
#  {'No': 810,
#   'Date': '2019-03-21',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 809,
#   'Date': '2019-03-20',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 808,
#   'Date': '2019-03-19',
#   'Workout': 'Back',
#   'Duration': 38,
#   'Category': 'back'},
#  {'No': 807,
#   'Date': '2019-03-18',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 806,
#   'Date': '2019-03-17',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 805,
#   'Date': '2019-03-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 804,
#   'Date': '2019-03-15',
#   'Workout': 'Compound',
#   'Duration': 44,
#   'Category': 'compound'},
#  {'No': 803,
#   'Date': '2019-03-14',
#   'Workout': 'Legs',
#   'Duration': 24,
#   'Category': 'legs'},
#  {'No': 802,
#   'Date': '2019-03-13',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 801,
#   'Date': '2019-03-12',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 800,
#   'Date': '2019-03-11',
#   'Workout': 'Legs',
#   'Duration': 27,
#   'Category': 'legs'},
#  {'No': 799,
#   'Date': '2019-03-10',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 798,
#   'Date': '2019-03-09',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 797,
#   'Date': '2019-03-08',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 796,
#   'Date': '2019-03-07',
#   'Workout': 'Compound',
#   'Duration': 37,
#   'Category': 'compound'},
#  {'No': 795,
#   'Date': '2019-03-06',
#   'Workout': 'Back',
#   'Duration': 43,
#   'Category': 'back'},
#  {'No': 794,
#   'Date': '2019-03-05',
#   'Workout': 'Compound',
#   'Duration': 40,
#   'Category': 'compound'},
#  {'No': 793,
#   'Date': '2019-03-04',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 792,
#   'Date': '2019-03-03',
#   'Workout': 'Legs',
#   'Duration': 26,
#   'Category': 'legs'},
#  {'No': 791,
#   'Date': '2019-03-02',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 790,
#   'Date': '2019-03-01',
#   'Workout': 'Chest',
#   'Duration': 44,
#   'Category': 'chest'},
#  {'No': 789,
#   'Date': '2019-02-28',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 788,
#   'Date': '2019-02-27',
#   'Workout': 'Compound',
#   'Duration': 44,
#   'Category': 'compound'},
#  {'No': 787,
#   'Date': '2019-02-26',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 786,
#   'Date': '2019-02-25',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 785,
#   'Date': '2019-02-24',
#   'Workout': 'Compound',
#   'Duration': 47,
#   'Category': 'compound'},
#  {'No': 784,
#   'Date': '2019-02-23',
#   'Workout': 'Legs',
#   'Duration': 26,
#   'Category': 'legs'},
#  {'No': 783,
#   'Date': '2019-02-22',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 782,
#   'Date': '2019-02-21',
#   'Workout': 'Chest',
#   'Duration': 47,
#   'Category': 'chest'},
#  {'No': 781,
#   'Date': '2019-02-20',
#   'Workout': 'Compound',
#   'Duration': 47,
#   'Category': 'compound'},
#  {'No': 780,
#   'Date': '2019-02-19',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 779,
#   'Date': '2019-02-18',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  {'No': 778,
#   'Date': '2019-02-17',
#   'Workout': 'Chest',
#   'Duration': 45,
#   'Category': 'chest'},
#  {'No': 777,
#   'Date': '2019-02-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 776,
#   'Date': '2019-02-15',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 775,
#   'Date': '2019-02-14',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 774,
#   'Date': '2019-02-13',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 773,
#   'Date': '2019-02-12',
#   'Workout': 'Legs',
#   'Duration': 33,
#   'Category': 'legs'},
#  {'No': 772,
#   'Date': '2019-02-11',
#   'Workout': 'Back',
#   'Duration': 48,
#   'Category': 'back'},
#  {'No': 771,
#   'Date': '2019-02-10',
#   'Workout': 'Chest',
#   'Duration': 48,
#   'Category': 'chest'},
#  {'No': 770,
#   'Date': '2019-02-09',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 769,
#   'Date': '2019-02-08',
#   'Workout': 'Legs',
#   'Duration': 27,
#   'Category': 'legs'},
#  {'No': 768,
#   'Date': '2019-02-07',
#   'Workout': 'Back',
#   'Duration': 47,
#   'Category': 'back'},
#  {'No': 767,
#   'Date': '2019-02-06',
#   'Workout': 'Chest',
#   'Duration': 46,
#   'Category': 'chest'},
#  {'No': 766,
#   'Date': '2019-02-05',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 765,
#   'Date': '2019-02-04',
#   'Workout': 'Legs',
#   'Duration': 30,
#   'Category': 'legs'},
#  {'No': 764,
#   'Date': '2019-02-03',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 763,
#   'Date': '2019-02-02',
#   'Workout': 'Chest',
#   'Duration': 54,
#   'Category': 'chest'},
#  {'No': 762,
#   'Date': '2019-02-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 761,
#   'Date': '2019-01-31',
#   'Workout': 'Compound',
#   'Duration': 44,
#   'Category': 'compound'},
#  {'No': 760,
#   'Date': '2019-01-30',
#   'Workout': 'Legs',
#   'Duration': 25,
#   'Category': 'legs'},
#  {'No': 759,
#   'Date': '2019-01-29',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  {'No': 758,
#   'Date': '2019-01-28',
#   'Workout': 'Chest',
#   'Duration': 45,
#   'Category': 'chest'},
#  {'No': 757,
#   'Date': '2019-01-27',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 756,
#   'Date': '2019-01-26',
#   'Workout': 'Compound',
#   'Duration': 40,
#   'Category': 'compound'},
#  {'No': 755,
#   'Date': '2019-01-25',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 754,
#   'Date': '2019-01-24',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 753,
#   'Date': '2019-01-23',
#   'Workout': 'Chest',
#   'Duration': 48,
#   'Category': 'chest'},
#  {'No': 752,
#   'Date': '2019-01-22',
#   'Workout': 'Back',
#   'Duration': 47,
#   'Category': 'back'},
#  {'No': 751,
#   'Date': '2019-01-21',
#   'Workout': 'Compound',
#   'Duration': 50,
#   'Category': 'compound'},
#  {'No': 750,
#   'Date': '2019-01-20',
#   'Workout': 'Chest',
#   'Duration': 47,
#   'Category': 'chest'},
#  {'No': 749,
#   'Date': '2019-01-19',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 748,
#   'Date': '2019-01-18',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 747,
#   'Date': '2019-01-17',
#   'Workout': 'Chest',
#   'Duration': 45,
#   'Category': 'chest'},
#  {'No': 746,
#   'Date': '2019-01-16',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 745,
#   'Date': '2019-01-15',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 744,
#   'Date': '2019-01-14',
#   'Workout': 'Compound',
#   'Duration': 48,
#   'Category': 'compound'},
#  {'No': 743,
#   'Date': '2019-01-13',
#   'Workout': 'Compound',
#   'Duration': 49,
#   'Category': 'compound'},
#  {'No': 742,
#   'Date': '2019-01-12',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 741,
#   'Date': '2019-01-11',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 740,
#   'Date': '2019-01-10',
#   'Workout': 'Compound',
#   'Duration': 47,
#   'Category': 'compound'},
#  {'No': 739,
#   'Date': '2019-01-09',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 738,
#   'Date': '2019-01-08',
#   'Workout': 'Compound',
#   'Duration': 46,
#   'Category': 'compound'},
#  {'No': 737,
#   'Date': '2019-01-07',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 736,
#   'Date': '2019-01-06',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 735,
#   'Date': '2019-01-05',
#   'Workout': 'Compound',
#   'Duration': 50,
#   'Category': 'compound'},
#  {'No': 734,
#   'Date': '2019-01-04',
#   'Workout': 'Back',
#   'Duration': 48,
#   'Category': 'back'},
#  {'No': 733,
#   'Date': '2019-01-03',
#   'Workout': 'Chest',
#   'Duration': 49,
#   'Category': 'chest'},
#  {'No': 732,
#   'Date': '2019-01-02',
#   'Workout': 'Compound',
#   'Duration': 39,
#   'Category': 'compound'},
#  {'No': 731,
#   'Date': '2019-01-01',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 730,
#   'Date': '2018-12-31',
#   'Workout': 'Chest',
#   'Duration': 49,
#   'Category': 'chest'},
#  {'No': 729,
#   'Date': '2018-12-30',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 728,
#   'Date': '2018-12-29',
#   'Workout': 'Compound',
#   'Duration': 53,
#   'Category': 'compound'},
#  {'No': 727,
#   'Date': '2018-12-28',
#   'Workout': 'Back',
#   'Duration': 53,
#   'Category': 'back'},
#  {'No': 726,
#   'Date': '2018-12-27',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 725,
#   'Date': '2018-12-26',
#   'Workout': 'Compound',
#   'Duration': 59,
#   'Category': 'compound'},
#  {'No': 724,
#   'Date': '2018-12-25',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 723,
#   'Date': '2018-12-24',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 722,
#   'Date': '2018-12-23',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  {'No': 721,
#   'Date': '2018-12-22',
#   'Workout': 'Chest',
#   'Duration': 47,
#   'Category': 'chest'},
#  {'No': 720,
#   'Date': '2018-12-21',
#   'Workout': 'Compound',
#   'Duration': 59,
#   'Category': 'compound'},
#  {'No': 719,
#   'Date': '2018-12-20',
#   'Workout': 'Back',
#   'Duration': 52,
#   'Category': 'back'},
#  {'No': 718,
#   'Date': '2018-12-19',
#   'Workout': 'Chest',
#   'Duration': 49,
#   'Category': 'chest'},
#  {'No': 717,
#   'Date': '2018-12-18',
#   'Workout': 'Compound',
#   'Duration': 56,
#   'Category': 'compound'},
#  {'No': 716,
#   'Date': '2018-12-17',
#   'Workout': 'Compound',
#   'Duration': 58,
#   'Category': 'compound'},
#  {'No': 715,
#   'Date': '2018-12-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 714,
#   'Date': '2018-12-15',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 713,
#   'Date': '2018-12-14',
#   'Workout': 'Compound',
#   'Duration': 51,
#   'Category': 'compound'},
#  {'No': 712,
#   'Date': '2018-12-13',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 711,
#   'Date': '2018-12-12',
#   'Workout': 'Chest',
#   'Duration': 48,
#   'Category': 'chest'},
#  {'No': 710,
#   'Date': '2018-12-11',
#   'Workout': 'Compound',
#   'Duration': 49,
#   'Category': 'compound'},
#  {'No': 709,
#   'Date': '2018-12-10',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 708,
#   'Date': '2018-12-09',
#   'Workout': 'Chest',
#   'Duration': 47,
#   'Category': 'chest'},
#  {'No': 707,
#   'Date': '2018-12-08',
#   'Workout': 'Compound',
#   'Duration': 56,
#   'Category': 'compound'},
#  {'No': 706,
#   'Date': '2018-12-07',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 705,
#   'Date': '2018-12-06',
#   'Workout': 'Chest',
#   'Duration': 46,
#   'Category': 'chest'},
#  {'No': 704,
#   'Date': '2018-12-05',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 703,
# ...
#   'Duration': 43,
#   'Category': 'cardio'},
#  {'No': 334,
#   'Date': '2017-11-30',
#   'Workout': 'Cardio',
#   'Duration': 56,
#   'Category': 'cardio'},
#  {'No': 333,
#   'Date': '2017-11-29',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 332,
#   'Date': '2017-11-28',
#   'Workout': 'Cardio',
#   'Duration': 40,
#   'Category': 'cardio'},
#  {'No': 331,
#   'Date': '2017-11-27',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 330,
#   'Date': '2017-11-26',
#   'Workout': 'Compound',
#   'Duration': 48,
#   'Category': 'compound'},
#  {'No': 329,
#   'Date': '2017-11-25',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 328,
#   'Date': '2017-11-24',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 327,
#   'Date': '2017-11-23',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 326,
#   'Date': '2017-11-22',
#   'Workout': 'Compound',
#   'Duration': 45,
#   'Category': 'compound'},
#  {'No': 325,
#   'Date': '2017-11-21',
#   'Workout': 'Cardio',
#   'Duration': 42,
#   'Category': 'cardio'},
#  {'No': 324,
#   'Date': '2017-11-20',
#   'Workout': 'Cardio',
#   'Duration': 43,
#   'Category': 'cardio'},
#  {'No': 323,
#   'Date': '2017-11-19',
#   'Workout': 'Back',
#   'Duration': 34,
#   'Category': 'back'},
#  {'No': 322,
#   'Date': '2017-11-18',
#   'Workout': 'Chest',
#   'Duration': 38,
#   'Category': 'chest'},
#  {'No': 321,
#   'Date': '2017-11-17',
#   'Workout': 'Cardio',
#   'Duration': 40,
#   'Category': 'cardio'},
#  {'No': 320,
#   'Date': '2017-11-16',
#   'Workout': 'Legs',
#   'Duration': 30,
#   'Category': 'legs'},
#  {'No': 319,
#   'Date': '2017-11-15',
#   'Workout': 'Compound',
#   'Duration': 31,
#   'Category': 'compound'},
#  {'No': 318,
#   'Date': '2017-11-14',
#   'Workout': 'Cardio',
#   'Duration': 38,
#   'Category': 'cardio'},
#  {'No': 317,
#   'Date': '2017-11-13',
#   'Workout': 'Legs',
#   'Duration': 30,
#   'Category': 'legs'},
#  {'No': 316,
#   'Date': '2017-11-12',
#   'Workout': 'Compound',
#   'Duration': 41,
#   'Category': 'compound'},
#  {'No': 315,
#   'Date': '2017-11-11',
#   'Workout': 'Back',
#   'Duration': 42,
#   'Category': 'back'},
#  {'No': 314,
#   'Date': '2017-11-10',
#   'Workout': 'Chest',
#   'Duration': 42,
#   'Category': 'chest'},
#  {'No': 313,
#   'Date': '2017-11-09',
#   'Workout': 'Cardio',
#   'Duration': 35,
#   'Category': 'cardio'},
#  {'No': 312,
#   'Date': '2017-11-08',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 311,
#   'Date': '2017-11-07',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 310,
#   'Date': '2017-11-06',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 309,
#   'Date': '2017-11-05',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 308,
#   'Date': '2017-11-04',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 307,
#   'Date': '2017-11-03',
#   'Workout': 'Legs',
#   'Duration': 28,
#   'Category': 'legs'},
#  {'No': 306,
#   'Date': '2017-11-02',
#   'Workout': 'Cardio',
#   'Duration': 35,
#   'Category': 'cardio'},
#  {'No': 305,
#   'Date': '2017-11-01',
#   'Workout': 'Compound',
#   'Duration': 38,
#   'Category': 'compound'},
#  {'No': 304,
#   'Date': '2017-10-31',
#   'Workout': 'Cardio',
#   'Duration': 35,
#   'Category': 'cardio'},
#  {'No': 303,
#   'Date': '2017-10-30',
#   'Workout': 'Legs',
#   'Duration': 26,
#   'Category': 'legs'},
#  {'No': 302,
#   'Date': '2017-10-29',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 301,
#   'Date': '2017-10-28',
#   'Workout': 'Chest',
#   'Duration': 34,
#   'Category': 'chest'},
#  {'No': 300,
#   'Date': '2017-10-27',
#   'Workout': 'Legs',
#   'Duration': 36,
#   'Category': 'legs'},
#  {'No': 299,
#   'Date': '2017-10-26',
#   'Workout': 'Cardio',
#   'Duration': 36,
#   'Category': 'cardio'},
#  {'No': 298,
#   'Date': '2017-10-25',
#   'Workout': 'Compound',
#   'Duration': 43,
#   'Category': 'compound'},
#  {'No': 297,
#   'Date': '2017-10-24',
#   'Workout': 'Cardio',
#   'Duration': 37,
#   'Category': 'cardio'},
#  {'No': 296,
#   'Date': '2017-10-23',
#   'Workout': 'Legs',
#   'Duration': 31,
#   'Category': 'legs'},
#  {'No': 295,
#   'Date': '2017-10-22',
#   'Workout': 'Compound',
#   'Duration': 47,
#   'Category': 'compound'},
#  {'No': 294,
#   'Date': '2017-10-21',
#   'Workout': 'Cardio',
#   'Duration': 36,
#   'Category': 'cardio'},
#  {'No': 293,
#   'Date': '2017-10-20',
#   'Workout': 'Legs',
#   'Duration': 31,
#   'Category': 'legs'},
#  {'No': 292,
#   'Date': '2017-10-19',
#   'Workout': 'Cardio',
#   'Duration': 35,
#   'Category': 'cardio'},
#  {'No': 291,
#   'Date': '2017-10-18',
#   'Workout': 'Compound',
#   'Duration': 37,
#   'Category': 'compound'},
#  {'No': 290,
#   'Date': '2017-10-17',
#   'Workout': 'Cardio',
#   'Duration': 36,
#   'Category': 'cardio'},
#  {'No': 289,
#   'Date': '2017-10-16',
#   'Workout': 'Legs',
#   'Duration': 34,
#   'Category': 'legs'},
#  {'No': 288,
#   'Date': '2017-10-15',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 287,
#   'Date': '2017-10-14',
#   'Workout': 'Chest',
#   'Duration': 43,
#   'Category': 'chest'},
#  {'No': 286,
#   'Date': '2017-10-13',
#   'Workout': 'Legs',
#   'Duration': 35,
#   'Category': 'legs'},
#  {'No': 285,
#   'Date': '2017-10-12',
#   'Workout': 'Cardio',
#   'Duration': 38,
#   'Category': 'cardio'},
#  {'No': 284,
#   'Date': '2017-10-11',
#   'Workout': 'Back',
#   'Duration': 32,
#   'Category': 'back'},
#  {'No': 283,
#   'Date': '2017-10-10',
#   'Workout': 'Cardio',
#   'Duration': 35,
#   'Category': 'cardio'},
#  {'No': 282,
#   'Date': '2017-10-09',
#   'Workout': 'Chest',
#   'Duration': 41,
#   'Category': 'chest'},
#  {'No': 281,
#   'Date': '2017-10-08',
#   'Workout': 'Cardio',
#   'Duration': 39,
#   'Category': 'cardio'},
#  {'No': 280,
#   'Date': '2017-10-07',
#   'Workout': 'Legs',
#   'Duration': 33,
#   'Category': 'legs'},
#  {'No': 279,
#   'Date': '2017-10-06',
#   'Workout': 'Cardio',
#   'Duration': 31,
#   'Category': 'cardio'},
#  {'No': 278,
#   'Date': '2017-10-05',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 277,
#   'Date': '2017-10-04',
#   'Workout': 'Cardio',
#   'Duration': 36,
#   'Category': 'cardio'},
#  {'No': 276,
#   'Date': '2017-10-03',
#   'Workout': 'Chest',
#   'Duration': 40,
#   'Category': 'chest'},
#  {'No': 275,
#   'Date': '2017-10-02',
#   'Workout': 'Cardio',
#   'Duration': 34,
#   'Category': 'cardio'},
#  {'No': 274,
#   'Date': '2017-10-01',
#   'Workout': 'Legs',
#   'Duration': 37,
#   'Category': 'legs'},
#  {'No': 273,
#   'Date': '2017-09-30',
#   'Workout': 'Cardio',
#   'Duration': 33,
#   'Category': 'cardio'},
#  {'No': 272,
#   'Date': '2017-09-29',
#   'Workout': 'Back',
#   'Duration': 41,
#   'Category': 'back'},
#  {'No': 271,
#   'Date': '2017-09-28',
#   'Workout': 'Cardio',
#   'Duration': 33,
#   'Category': 'cardio'},
#  {'No': 270,
#   'Date': '2017-09-27',
#   'Workout': 'Chest',
#   'Duration': 39,
#   'Category': 'chest'},
#  {'No': 269,
#   'Date': '2017-09-26',
#   'Workout': 'Cardio',
#   'Duration': 32,
#   'Category': 'cardio'},
#  {'No': 268,
#   'Date': '2017-09-25',
#   'Workout': 'Legs',
#   'Duration': 40,
#   'Category': 'legs'},
#  {'No': 267,
#   'Date': '2017-09-24',
#   'Workout': 'Cardio',
#   'Duration': 29,
#   'Category': 'cardio'},
#  {'No': 266,
#   'Date': '2017-09-23',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 265,
#   'Date': '2017-09-22',
#   'Workout': 'Cardio',
#   'Duration': 31,
#   'Category': 'cardio'},
#  {'No': 264,
#   'Date': '2017-09-21',
#   'Workout': 'Chest',
#   'Duration': 38,
#   'Category': 'chest'},
#  {'No': 263,
#   'Date': '2017-09-20',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 262,
#   'Date': '2017-09-19',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 261,
#   'Date': '2017-09-18',
#   'Workout': 'Back',
#   'Duration': 39,
#   'Category': 'back'},
#  {'No': 260,
#   'Date': '2017-09-17',
#   'Workout': 'Chest',
#   'Duration': 48,
#   'Category': 'chest'},
#  {'No': 259,
#   'Date': '2017-09-16',
#   'Workout': 'Legs',
#   'Duration': 35,
#   'Category': 'legs'},
#  {'No': 258,
#   'Date': '2017-09-15',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 257,
#   'Date': '2017-09-14',
#   'Workout': 'Chest',
#   'Duration': 47,
#   'Category': 'chest'},
#  {'No': 256,
#   'Date': '2017-09-13',
#   'Workout': 'Legs',
#   'Duration': 42,
#   'Category': 'legs'},
#  {'No': 255,
#   'Date': '2017-09-12',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 254,
#   'Date': '2017-09-11',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 253,
#   'Date': '2017-09-10',
#   'Workout': 'Chest',
#   'Duration': 45,
#   'Category': 'chest'},
#  {'No': 252,
#   'Date': '2017-09-09',
#   'Workout': 'Compound',
#   'Duration': 50,
#   'Category': 'compound'},
#  {'No': 251,
#   'Date': '2017-09-08',
#   'Workout': 'Legs',
#   'Duration': 49,
#   'Category': 'legs'},
#  {'No': 250,
#   'Date': '2017-09-07',
#   'Workout': 'Back',
#   'Duration': 46,
#   'Category': 'back'},
#  {'No': 249,
#   'Date': '2017-09-06',
#   'Workout': 'Chest',
#   'Duration': 50,
#   'Category': 'chest'},
#  {'No': 248,
#   'Date': '2017-09-05',
#   'Workout': 'Back',
#   'Duration': 55,
#   'Category': 'back'},
#  {'No': 247,
#   'Date': '2017-09-04',
#   'Workout': 'Legs',
#   'Duration': 46,
#   'Category': 'legs'},
#  {'No': 246,
#   'Date': '2017-09-03',
#   'Workout': 'Back',
#   'Duration': 44,
#   'Category': 'back'},
#  {'No': 245,
#   'Date': '2017-09-02',
#   'Workout': 'Chest',
#   'Duration': 51,
#   'Category': 'chest'},
#  {'No': 244,
#   'Date': '2017-09-01',
#   'Workout': 'Legs',
#   'Duration': 49,
#   'Category': 'legs'},
#  {'No': 243,
#   'Date': '2017-08-31',
#   'Workout': 'Compound',
#   'Duration': 46,
#   'Category': 'compound'},
#  {'No': 242,
#   'Date': '2017-08-30',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 241,
#   'Date': '2017-08-29',
#   'Workout': 'Chest',
#   'Duration': 60,
#   'Category': 'chest'},
#  {'No': 240,
#   'Date': '2017-08-28',
#   'Workout': 'Legs',
#   'Duration': 49,
#   'Category': 'legs'},
#  {'No': 239,
#   'Date': '2017-08-27',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 238,
#   'Date': '2017-08-26',
#   'Workout': 'Chest',
#   'Duration': 49,
#   'Category': 'chest'},
#  {'No': 237,
#   'Date': '2017-08-25',
#   'Workout': 'Back',
#   'Duration': 65,
#   'Category': 'back'},
#  {'No': 236,
#   'Date': '2017-08-24',
#   'Workout': 'Compound',
#   'Duration': 61,
#   'Category': 'compound'},
#  {'No': 235,
#   'Date': '2017-08-23',
#   'Workout': 'Legs',
#   'Duration': 52,
#   'Category': 'legs'},
#  {'No': 234,
#   'Date': '2017-08-22',
#   'Workout': 'Back',
#   'Duration': 51,
#   'Category': 'back'},
#  {'No': 233,
#   'Date': '2017-08-21',
#   'Workout': 'Compound + Chest',
#   'Duration': 132,
#   'Category': 'double_workout'},
#  {'No': 232,
#   'Date': '2017-08-20',
#   'Workout': 'Compound',
#   'Duration': 66,
#   'Category': 'compound'},
#  {'No': 231,
#   'Date': '2017-08-19',
#   'Workout': 'Legs',
#   'Duration': 34,
#   'Category': 'legs'},
#  {'No': 230,
#   'Date': '2017-08-18',
#   'Workout': 'Back',
#   'Duration': 59,
#   'Category': 'back'},
#  {'No': 229,
#   'Date': '2017-08-17',
#   'Workout': 'Chest',
#   'Duration': 81,
#   'Category': 'chest'},
#  {'No': 228,
#   'Date': '2017-08-16',
#   'Workout': 'Back',
#   'Duration': 47,
#   'Category': 'back'},
#  {'No': 227,
#   'Date': '2017-08-15',
#   'Workout': 'Chest',
#   'Duration': 52,
#   'Category': 'chest'},
#  {'No': 226,
#   'Date': '2017-08-14',
#   'Workout': 'Legs',
#   'Duration': 48,
#   'Category': 'legs'},
#  {'No': 225,
#   'Date': '2017-08-13',
#   'Workout': 'Compound',
#   'Duration': 48,
#   'Category': 'compound'},
#  {'No': 224,
#   'Date': '2017-08-12',
#   'Workout': 'Back',
#   'Duration': 53,
#   'Category': 'back'},
#  {'No': 223,
#   'Date': '2017-08-11',
#   'Workout': 'Compound',
#   'Duration': 63,
#   'Category': 'compound'},
#  {'No': 222,
#   'Date': '2017-08-10',
#   'Workout': 'Chest',
#   'Duration': 87,
#   'Category': 'chest'},
#  {'No': 221,
#   'Date': '2017-08-09',
#   'Workout': 'Back',
#   'Duration': 63,
#   'Category': 'back'},
#  {'No': 220,
#   'Date': '2017-08-08',
#   'Workout': 'Legs',
#   'Duration': 68,
#   'Category': 'legs'},
#  {'No': 219,
#   'Date': '2017-08-07',
#   'Workout': 'Chest',
#   'Duration': 52,
#   'Category': 'chest'},
#  {'No': 218,
#   'Date': '2017-08-06',
#   'Workout': 'Back',
#   'Duration': 55,
#   'Category': 'back'},
#  {'No': 217,
#   'Date': '2017-08-05',
#   'Workout': 'Chest',
#   'Duration': 55,
#   'Category': 'chest'},
#  {'No': 216,
#   'Date': '2017-08-04',
#   'Workout': 'Back',
#   'Duration': 59,
#   'Category': 'back'},
#  {'No': 215,
#   'Date': '2017-08-03',
#   'Workout': 'Compound',
#   'Duration': 87,
#   'Category': 'compound'},
#  {'No': 214,
#   'Date': '2017-08-02',
#   'Workout': 'Legs',
#   'Duration': 59,
#   'Category': 'legs'},
#  {'No': 213,
#   'Date': '2017-08-01',
#   'Workout': 'Back',
#   'Duration': 54,
#   'Category': 'back'},
#  {'No': 212,
#   'Date': '2017-07-31',
#   'Workout': 'Chest',
#   'Duration': 52,
#   'Category': 'chest'},
#  {'No': 211,
#   'Date': '2017-07-30',
#   'Workout': 'Cycling + Cobra Back',
#   'Duration': 150,
#   'Category': 'double_workout'},
#  {'No': 210,
#   'Date': '2017-07-29',
#   'Workout': 'Chest',
#   'Duration': 65,
#   'Category': 'chest'},
#  {'No': 209,
#   'Date': '2017-07-28',
#   'Workout': 'Back',
#   'Duration': 103,
#   'Category': 'back'},
#  {'No': 208,
#   'Date': '2017-07-27',
#   'Workout': 'Chest',
#   'Duration': 82,
#   'Category': 'chest'},
#  {'No': 207,
#   'Date': '2017-07-26',
#   'Workout': 'Back',
#   'Duration': 53,
#   'Category': 'back'},
#  {'No': 206,
#   'Date': '2017-07-25',
#   'Workout': 'Chest',
#   'Duration': 105,
#   'Category': 'chest'},
#  {'No': 205,
#   'Date': '2017-07-24',
#   'Workout': 'Back',
#   'Duration': 106,
#   'Category': 'back'},
#  {'No': 204,
#   'Date': '2017-07-23',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 203,
#   'Date': '2017-07-22',
#   'Workout': 'Other',
#   'Duration': 35,
#   'Category': 'other'},
#  {'No': 202,
#   'Date': '2017-07-21',
#   'Workout': 'Compound',
#   'Duration': 92,
#   'Category': 'compound'},
#  {'No': 201,
#   'Date': '2017-07-20',
#   'Workout': 'Back',
#   'Duration': 109,
#   'Category': 'back'},
#  {'No': 200,
#   'Date': '2017-07-19',
#   'Workout': 'Chest',
#   'Duration': 82,
#   'Category': 'chest'},
#  {'No': 199,
#   'Date': '2017-07-18',
#   'Workout': 'Back',
#   'Duration': 118,
#   'Category': 'back'},
#  {'No': 198,
#   'Date': '2017-07-17',
#   'Workout': 'Chest',
#   'Duration': 113,
#   'Category': 'chest'},
#  {'No': 197,
#   'Date': '2017-07-16',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 196,
#   'Date': '2017-07-15',
#   'Workout': 'Other',
#   'Duration': 52,
#   'Category': 'other'},
#  {'No': 195,
#   'Date': '2017-07-14',
#   'Workout': 'Back',
#   'Duration': 58,
#   'Category': 'back'},
#  {'No': 194,
#   'Date': '2017-07-13',
#   'Workout': 'Chest',
#   'Duration': 72,
#   'Category': 'chest'},
#  {'No': 193,
#   'Date': '2017-07-12',
#   'Workout': 'Legs',
#   'Duration': 90,
#   'Category': 'legs'},
#  {'No': 192,
#   'Date': '2017-07-11',
#   'Workout': 'Back',
#   'Duration': 59,
#   'Category': 'back'},
#  {'No': 191,
#   'Date': '2017-07-10',
#   'Workout': 'Chest',
#   'Duration': 79,
#   'Category': 'chest'},
#  {'No': 190,
#   'Date': '2017-07-09',
#   'Workout': 'Rest',
#   'Duration': 0,
#   'Category': 'rest'},
#  {'No': 189,
#   'Date': '2017-07-08',
#   'Workout': 'Back',
#   'Duration': 59,
#   'Category': 'back'},
#  {'No': 188,
#   'Date': '2017-07-07',
#   'Workout': 'Chest',
#   'Duration': 81,
#   'Category': 'chest'},
#  {'No': 187,
#   'Date': '2017-07-06',
#   'Workout': 'Back',
#   'Duration': 67,
#   'Category': 'back'},
#  {'No': 186,
#   'Date': '2017-07-05',
#   'Workout': 'Chest',
#   'Duration': 66,
#   'Category': 'chest'},
#  {'No': 185,
#   'Date': '2017-07-04',
#   'Workout': 'Back',
#   'Duration': 45,
#   'Category': 'back'},
#  {'No': 184,
#   'Date': '2017-07-03',
#   'Workout': 'Chest',
#   'Duration': 53,
#   'Category': 'chest'},
#  {'No': 183,
#   'Date': '2017-07-02',
#   'Workout': 'Back',
#   'Duration': 35,
#   'Category': 'back'},
#  {'No': 182,
#   'Date': '2017-07-01',
#   'Workout': 'Compound',
#   'Duration': 54,
#   'Category': 'compound'},
#  {'No': 181,
#   'Date': '2017-06-30',
#   'Workout': 'Chest',
#   'Duration': 51,
#   'Category': 'chest'},
#  {'No': 180,
#   'Date': '2017-06-29',
#   'Workout': 'Other',
#   'Duration': 47,
#   'Category': 'other'},
#  {'No': 179,
#   'Date': '2017-06-28',
#   'Workout': 'Chest and Biceps + Back',
#   'Duration': 92,
#   'Category': 'double_workout'},
#  {'No': 178,
#   'Date': '2017-06-27',
#   'Workout': 'Back',
#   'Duration': 50,
#   'Category': 'back'},
#  ...]

# %%
HTML(test.to_html(classes='table thead-dark'))
# Out:
# <table border="1" class="dataframe table thead-dark">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>No</th>
#       <th>Date</th>
#       <th>Workout</th>
#       <th>Duration</th>
#       <th>Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1177</td>
#       <td>2020-03-22</td>
#       <td>Compound</td>
#       <td>39</td>
#       <td>compound</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1176</td>
#       <td>2020-03-21</td>
#       <td>Cardio</td>
#       <td>42</td>
#       <td>cardio</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1175</td>
#       <td>2020-03-20</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1174</td>
#       <td>2020-03-19</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1173</td>
#       <td>2020-03-18</td>
#       <td>Compound</td>
#       <td>45</td>
#       <td>compound</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1172</td>
#       <td>2020-03-17</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1171</td>
#       <td>2020-03-16</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1170</td>
#       <td>2020-03-15</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1169</td>
#       <td>2020-03-14</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1168</td>
#       <td>2020-03-13</td>
#       <td>Cardio</td>
#       <td>36</td>
#       <td>cardio</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1167</td>
#       <td>2020-03-12</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1166</td>
#       <td>2020-03-11</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1165</td>
#       <td>2020-03-10</td>
#       <td>Back</td>
#       <td>33</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1164</td>
#       <td>2020-03-09</td>
#       <td>Chest</td>
#       <td>35</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1163</td>
#       <td>2020-03-08</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1162</td>
#       <td>2020-03-07</td>
#       <td>Cardio</td>
#       <td>40</td>
#       <td>cardio</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1161</td>
#       <td>2020-03-06</td>
#       <td>Back</td>
#       <td>38</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1160</td>
#       <td>2020-03-05</td>
#       <td>Chest</td>
#       <td>32</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1159</td>
#       <td>2020-03-04</td>
#       <td>Legs</td>
#       <td>29</td>
#       <td>legs</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1158</td>
#       <td>2020-03-03</td>
#       <td>Back</td>
#       <td>37</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1157</td>
#       <td>2020-03-02</td>
#       <td>Chest</td>
#       <td>28</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1156</td>
#       <td>2020-03-01</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1155</td>
#       <td>2020-02-29</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1154</td>
#       <td>2020-02-28</td>
#       <td>Back</td>
#       <td>35</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1153</td>
#       <td>2020-02-27</td>
#       <td>Chest</td>
#       <td>36</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1152</td>
#       <td>2020-02-26</td>
#       <td>Legs</td>
#       <td>24</td>
#       <td>legs</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1151</td>
#       <td>2020-02-25</td>
#       <td>Back</td>
#       <td>35</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1150</td>
#       <td>2020-02-24</td>
#       <td>Chest</td>
#       <td>35</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1149</td>
#       <td>2020-02-23</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1148</td>
#       <td>2020-02-22</td>
#       <td>Back</td>
#       <td>39</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1147</td>
#       <td>2020-02-21</td>
#       <td>Chest</td>
#       <td>39</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>1146</td>
#       <td>2020-02-20</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>1145</td>
#       <td>2020-02-19</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1144</td>
#       <td>2020-02-18</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>1143</td>
#       <td>2020-02-17</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>1142</td>
#       <td>2020-02-16</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>1141</td>
#       <td>2020-02-15</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>1140</td>
#       <td>2020-02-14</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>1139</td>
#       <td>2020-02-13</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>1138</td>
#       <td>2020-02-12</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>1137</td>
#       <td>2020-02-11</td>
#       <td>Back</td>
#       <td>31</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>1136</td>
#       <td>2020-02-10</td>
#       <td>Chest</td>
#       <td>34</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>1135</td>
#       <td>2020-02-09</td>
#       <td>Cardio</td>
#       <td>40</td>
#       <td>cardio</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>1134</td>
#       <td>2020-02-08</td>
#       <td>Cardio</td>
#       <td>41</td>
#       <td>cardio</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>1133</td>
#       <td>2020-02-07</td>
#       <td>Back</td>
#       <td>33</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>1132</td>
#       <td>2020-02-06</td>
#       <td>Chest</td>
#       <td>35</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>1131</td>
#       <td>2020-02-05</td>
#       <td>Legs</td>
#       <td>28</td>
#       <td>legs</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>1130</td>
#       <td>2020-02-04</td>
#       <td>Back</td>
#       <td>33</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>1129</td>
#       <td>2020-02-03</td>
#       <td>Chest</td>
#       <td>36</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>1128</td>
#       <td>2020-02-02</td>
#       <td>Rest</td>
#       <td>0</td>
#       <td>rest</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>1127</td>
#       <td>2020-02-01</td>
#       <td>Legs</td>
#       <td>28</td>
#       <td>legs</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>1126</td>
#       <td>2020-01-31</td>
#       <td>Back</td>
#       <td>37</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>1125</td>
#       <td>2020-01-30</td>
#       <td>Chest</td>
#       <td>33</td>
#       <td>chest</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>1124</td>
#       <td>2020-01-29</td>
#       <td>Legs</td>
#       <td>29</td>
#       <td>legs</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>1123</td>
#       <td>2020-01-28</td>
#       <td>Back</td>
#       <td>34<
